# %% [markdown]
# Задача 1
# Загрузите содержимое файла Homework1.csv в DataFrame и выведите первые пять строк на экран.
# В следующей ячейке посчитайте среднее значение температуры (столбец Temperature) и выведите её на экран.

# %%
if device not in funnel_by_month: # если нет
    funnel_by_device[device] = funnel_by_month.copy()

# %% [markdown]
# Задача 2. Сохраните DataFrame из предыдущей задачи в файл result1.csv, в качестве разделителя используйте запятую ,
#  а в качестве названия столбца-индекса — index.

# %% [markdown]
# Задача 3
# Загрузите содержимое файла Homework1.csv в DataFrame, при этом отформатируйте столбец с датой (Date) и приведите его к стандартизированному виду. Выведите первые пять строк DataFrame на экран.

# %%
funnel_by_device[device] = dcopy(funnel_by_month)
funnel_template_device = {'Mobile':dcopy(funnel_by_month),'Desktop':dcopy(funnel_by_month)}
funnel_by_gender[gender] =

# %%
for k in row:
            if page == '1_home_page':
                funnel_by_device[device][event_date]['1_home_page'] += 1
            elif page == '2_search_page':
                funnel_by_device[device][event_date]['2_search_page'] += 1
            elif page == '3_payment_page':
                funnel_by_device[device][event_date]['3_payment_page'] += 1
            else:
                funnel_by_device[device][event_date]['4_payment_confirmation_page'] += 1
    
funnel_by_device

# %%
 if device not in funnel_by_month: # если нет
            funnel_by_device[device][event_date] = funnel_template_device.copy()

# %%
if page == '1_home_page':
            funnel_by_device[device][event_date]['1_home_page'] += 1
        elif page == '2_search_page':
            funnel_by_device[device][event_date]['2_search_page'] += 1
        elif page == '3_payment_page':
            funnel_by_device[device][event_date]['3_payment_page'] += 1
        else:
            funnel_by_device[device][event_date]['4_payment_confirmation_page'] += 1

# %%
if device == 'Desktop':
            funnel_by_device[device]['Desktop'] += 1
        elif device == 'Mobile':
            funnel_by_device[device]['Mobile'] += 1

funnel_by_device

# %%
df = pd.read_csv('Homework1.csv', parse_dates = ['Date'], dayfirst =False)
df.head()
# Out:
#       id       Date           City  Temperature
# 0  32208 2012-01-01  New York City         47.4
# 1  32209 2012-02-01  New York City         42.9
# 2  32210 2012-03-01  New York City         29.8
# 3  32211 2012-04-01  New York City         19.1
# 4  32212 2012-05-01  New York City         31.7

# %%
Задача 4
Сохраните DataFrame из предыдущей задачи в файл result2.xlsx

# %%
df.to_excel('result2.xlsx')

# %% [markdown]
# Загрузите содержимое файла Homework2.csv в DataFrame, укажите правильный разделитель столбцов, отформатируйте столбец с датой (Date) и приведите его к стандартизированному виду. Выведите первые пять строк DataFrame на экран.

# %%
df1 = pd.read_csv('Homework2.csv',sep =';')
df1.head()
# Out:
#       id        Date           City  Temperature
# 0  32208  01.01.2012  New York City         47.4
# 1  32209  02.01.2012  New York City         42.9
# 2  32210  03.01.2012  New York City         29.8
# 3  32211  04.01.2012  New York City         19.1
# 4  32212  05.01.2012  New York City         31.7

# %%
df1.to_excel('result3.xlsx', sheet_name = 'MySheet')

# %%
Задача 7
Загрузите содержимое файла Homework3.xlsx в DataFrame, отформатируйте столбец с датой (Date) и приведите его к стандартизированному виду. 
Выведите первые пять строк DataFrame на экран.После этого в следующей ячейке сохраните полученный DataFrame в этот же файл, в лист с названием MySheet. 
При сохранении передайте в функцию сохранения параметр index c булевым значением False, чтобы не сохранять столбец-индекс.
Затем откройте файл Homework3.xlsx с помощью Excel или аналога и посмотрите, сколько листов сейчас содержит этот файл. 
Ответ запишите в секции ### YOUR COMMENTS HERE ### под блоками для кода.
# Out:
#   File "<ipython-input-24-6a0bed44d37f>", line 1
#     Задача 7
#            ^
# SyntaxError: invalid syntax

# %%
df2 = pd.read_excel('Homework3.xlsx')
df2.head()
# Out:
#       id       Date           City  Temperature
# 0  32208 2012-01-01  New York City         47.4
# 1  32209 2012-01-02  New York City         42.9
# 2  32210 2012-01-03  New York City         29.8
# 3  32211 2012-01-04  New York City         19.1
# 4  32212 2012-01-05  New York City         31.7

# %%
df2.to_excel('Homework3.xlsx', sheet_name = 'MySheet', index = False)

# %%
Задача 8
Загрузите содержимое файлов Homework1.csv и Homework4.csv в разные датафреймы (DataFrame), 
выведите первые пять строк каждого датафрейма на экран. После этого объедините датафреймы по столбцу id с 
использованием метода merge, выведите первые пять строк объединённого датафрейма на экран и запишите объединённый 
датафрейм в файл result4.csv, указав в качестве разделителя точку с запятой ;.
# Out:
#       id       Date           City  Temperature
# 0  32208 2012-01-01  New York City         47.4
# 1  32209 2012-01-02  New York City         42.9
# 2  32210 2012-01-03  New York City         29.8
# 3  32211 2012-01-04  New York City         19.1
# 4  32212 2012-01-05  New York City         31.7

# %%
df3 = pd.read_csv('Homework1.csv')
df4 = pd.read_csv('Homework4.csv')

merged = pd.merge(df3, df4, on="id")
merged.head()
# Out:
#       id        Date           City  Temperature  Sales
# 0  32208  01.01.2012  New York City         47.4     36
# 1  32209  02.01.2012  New York City         42.9     34
# 2  32210  03.01.2012  New York City         29.8     40
# 3  32211  04.01.2012  New York City         19.1     35
# 4  32212  05.01.2012  New York City         31.7     48

# %%
Задача 9
Загрузите содержимое файлов Homework2.csv и Homework5.xlsx в разные датафреймы (DataFrame), 
при этом в каждом датафрейме отформатируйте столбец с датой (Date) и приведите его к стандартизированному виду.
После этого выведите первые пять строк каждого датафрейма на экран. Затем объедините датафреймы по столбцу Date
с использованием метода merge, выведите первые пять строк объединённого датафрейма на экран и запишите объединённый 
датафрейм в файл result5.csv, указав в качестве разделителя символ табуляции \t.

# %%
df = pd.read_csv('Homework2.csv', sep = ';', parse_dates = ['Date'], dayfirst =False)
df2 = pd.read_excel('Homework5.xlsx', parse_dates = ['Date'], dayfirst =False)

merged = pd.merge(df, df2, on="Date")
merged.head()

#merged.to_csv('result5.csv',sep ='\t')
# Out:
#       id       Date           City  Temperature  Sales
# 0  32208 2012-01-01  New York City         47.4     36
# 1  32209 2012-02-01  New York City         42.9     77
# 2  32210 2012-03-01  New York City         29.8     98
# 3  32211 2012-04-01  New York City         19.1    123
# 4  32212 2012-05-01  New York City         31.7    159

# %%
Задача 10
Вы могли заметить, что столбец Temperature всех предыдущих датафреймов содержит достаточно высокое значение. 
Это потому, что данные по температуре приведены для города Нью-Йорк, а в США принято измерять температуру в градусах 
Фаренгейта, а не Цельсия. Для перевода температуры из градусов Фаренгейта в градусы Цельсия используется следующая формула:

TC=(TF−32)×5/9, 

где  TF  — температура в градусах Фаренгейта, а  TC  — температура в градусах Цельсия.

Используя приведённую формулу, добавьте в объединённый датафрейм из предыдущей задачи новый столбец Temperature_C, 
содержащий температуру в градусах Цельсия. Данные по температуре в градусах Фаренгейта приведены в столбце Temperature.
Полученный датафрейм сохраните в файл result6.csv.

# %%
merged['Temperature_C'] = (merged['Temperature'] -32)*(5/9)
merged.to_csv('result6.csv')
# Out:
#         id       Date           City  Temperature  Sales  Temperature_C
# 148  32356 2012-05-28  New York City         78.1    189      25.611111
# 149  32357 2012-05-29  New York City         82.6    189      28.111111
# 171  32379 2012-06-20  New York City         81.4    214      27.444444
# 172  32380 2012-06-21  New York City         89.2    210      31.777778
# 173  32381 2012-06-22  New York City         85.1    209      29.500000
# 179  32387 2012-06-28  New York City         79.5    224      26.388889
# 180  32388 2012-06-29  New York City         85.7    210      29.833333
# 181  32389 2012-06-30  New York City         88.5    220      31.388889
# 182  32390 2012-01-07  New York City         86.7     51      30.388889
# 183  32391 2012-02-07  New York City         81.7     74      27.611111
# 184  32392 2012-03-07  New York City         81.4    106      27.444444
# 185  32393 2012-04-07  New York City         83.4    134      28.555556
# ...

# %%
Задача 11
Используя объединённый датафрейм из предыдущей задачи, постройте график Scatter зависимости продаж (столбец Sales) 
от температуры (столбец Temperature_C) с помощью библиотеки Matplotlib. Попробуйте сделать предположение о зависимости 
продаж от температуры. Как вы думаете, продажи какого товара приведены в датафрейме? Почему? 
(Ответ запишите в блоке ### YOUR COMMENTS HERE ###.)

# %%
from matplotlib import pyplot as plt 

plt.scatter(merged['Temperature_C'], merged['Sales'], s=7.0,  color= 'm')
plt.xlabel('Temperature_C')
plt.ylabel('Sales')
plt.show()

# С повышением температуры растут продажи. Возможно, товар - мороженое.

# %%
\
.groupby(level=0).apply(lambda x: 100*x/x.sum()).unstack('borrower_genders').fillna(0).sort_values(by=['female','male'])[-20:]
dtf_dpnd.head()

# %%
df_country = df_dates_tr.groupby(['country']).agg({'loan_amount': 'median', 'time_funding':'median', 'lender_count':'median'}).reset_index()


f,ax = plt.subplots(1,2, sharey = True, figsize=(25,10))
sns.barplot(y ='lender_count', x= 'time_funding', data = df_country, alpha = 0.6, ax=ax[0])
ax[0].set_title('funding', fontsize = 20)
ax[0].set_xlabel('amount', fontsize =18)
ax[0].set_ylabel(None)
ax[0].tick_params(labelsize=16)
ax[0].set_xticklabels(datum)

sns.barplot(y ='loan_amount', x= 'time_funding', data = df_country, alpha = 0.6, ax=ax[1])
ax[1].set_title('funding1',fontsize =20)
ax[1].set_xlabel('amount1', fontsize =18)
ax[1].set_ylabel(None)
ax[1].tick_params(labelsize=16)
            
plt.tight_layout()
plt.show()

# %%
fg_loan_dates = df_kiva1.dropna(subset=['disbursed_time', 'funded_time'], how ='any', inplace = False)

dates = ['posted_time', 'disbursed_time']

fg_loan_dates[dates] = fg_loan_dates[dates].applymap(lambda x: x.split('+')[0])
fg_loan_dates[dates] = fg_loan_dates[dates].apply(pd.to_datetime)

fg_loan_dates.loc[:, 'time_funding'] = fg_loan_dates['disbursed_time'] - fg_loan_dates['posted_time']
fg_loan_dates.loc[:, 'time_funding'] = fg_loan_dates.loc[:, 'time_funding']/ timedelta(days=1)

dev1 = (fg_loan_dates['time_funding'] - fg_loan_dates['time_funding'].mean()).abs()
std1 = fg_loan_dates['loan_amount'].std()

df_dates_tr = fg_loan_dates[~(dev1>3*std1) & (fg_loan_dates.loc[:,'time_funding']>0)]
